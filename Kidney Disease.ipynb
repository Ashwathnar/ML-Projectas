# %%
#import nessary module
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#using pandas and read dataset
df=pd.read_csv("kidney_disease.csv")
df
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
df.drop("id",axis=1,inplace=True)

# %%
#feature is short form,i change full form of the features

df=df.rename(columns={'id': 'Identification',
    'age': 'Age',
    'bp': 'Blood Pressure',
    'sg': 'Specific Gravity',
    'al': 'Albumin',
    'su': 'Sugar',
    'rbc': 'Red Blood Cells',
    'pc': 'Pus Cell',
    'pcc': 'Pus Cell Clumps',
    'ba': 'Bacteria',
    'bgr': 'Blood GlucoseRandom',
    'bu': 'Blood Urea',
    'sc': 'Serum Creatinine',
    'sod': 'Sodium',
    'pot': 'Potassium',
    'hemo': 'Hemoglobin',
    'pcv': 'Packed Cell Volume',
    'wc': 'White Blood Cell Count',
    'rc': 'Red Blood Cell Count',
    'htn': 'Hypertension',
    'dm': 'Diabetes Mellitus',
    'cad': 'Coronary Artery Disease',
    'appet': 'Appetite',
    'pe': 'Pedal Edema',
    'ane': 'Anemia',
    'classification': 'Classification'})

# %%
df
# Out:
#       Age  Blood Pressure  Specific Gravity  Albumin  Sugar Red Blood Cells  \
# 0    48.0            80.0             1.020      1.0    0.0             NaN
# 1     7.0            50.0             1.020      4.0    0.0             NaN
# 2    62.0            80.0             1.010      2.0    3.0          normal
# 3    48.0            70.0             1.005      4.0    0.0          normal
# 4    51.0            80.0             1.010      2.0    0.0          normal
# ..    ...             ...               ...      ...    ...             ...
# 395  55.0            80.0             1.020      0.0    0.0          normal
# 396  42.0            70.0             1.025      0.0    0.0          normal
# 397  12.0            80.0             1.020      0.0    0.0          normal
# 398  17.0            60.0             1.025      0.0    0.0          normal
# 399  58.0            80.0             1.025      0.0    0.0          normal
#
# ...

# %%
#check the information of the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      391 non-null    float64
#  1   Blood Pressure           388 non-null    float64
#  2   Specific Gravity         353 non-null    float64
#  3   Albumin                  354 non-null    float64
#  4   Sugar                    351 non-null    float64
#  5   Red Blood Cells          248 non-null    object
#  6   Pus Cell                 335 non-null    object
#  7   Pus Cell Clumps          396 non-null    object
#  8   Bacteria                 396 non-null    object
#  9   Blood GlucoseRandom      356 non-null    float64
#  10  Blood Urea               381 non-null    float64
#  11  Serum Creatinine         383 non-null    float64
#  12  Sodium                   313 non-null    float64
#  13  Potassium                312 non-null    float64
# ...

# %%
# Feature store numbers but feature datatype is object,this feature has wrong datatype ,i change the datatype
#using pandas and to_numeric() function

numobj=['Packed Cell Volume','White Blood Cell Count','Red Blood Cell Count']
for nu in numobj:
    df[nu]=pd.to_numeric(df[nu],errors="coerce")

# %%
# i cheking the feature datatype change or not
for b in numobj:
    print(nu , ':')
    print(df.dtypes[b])
# Out:
# Red Blood Cell Count :
# float64
# Red Blood Cell Count :
# float64
# Red Blood Cell Count :
# float64

# %%
#check the nullvalues in the features and total number of null valuese,i print desending order

df.isnull().sum().sort_values(ascending=False)
# Out:
# Red Blood Cells            152
# Red Blood Cell Count       131
# White Blood Cell Count     106
# Potassium                   88
# Sodium                      87
# Packed Cell Volume          71
# Pus Cell                    65
# Hemoglobin                  52
# Sugar                       49
# Specific Gravity            47
# Albumin                     46
# Blood GlucoseRandom         44
# Blood Urea                  19
# Serum Creatinine            17
# Blood Pressure              12
# Age                          9
# Bacteria                     4
# Pus Cell Clumps              4
# Hypertension                 2
# Diabetes Mellitus            2
# Coronary Artery Disease      2
# Appetite                     1
# Pedal Edema                  1
# Anemia                       1
# Classification               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Blood Pressure', 'Specific Gravity', 'Albumin', 'Sugar',
#        'Red Blood Cells', 'Pus Cell', 'Pus Cell Clumps', 'Bacteria',
#        'Blood GlucoseRandom', 'Blood Urea', 'Serum Creatinine', 'Sodium',
#        'Potassium', 'Hemoglobin', 'Packed Cell Volume',
#        'White Blood Cell Count', 'Red Blood Cell Count', 'Hypertension',
#        'Diabetes Mellitus', 'Coronary Artery Disease', 'Appetite',
#        'Pedal Edema', 'Anemia', 'Classification'],
#       dtype='object')

# %%
# this dataset features has null values in "object"datatype and "int "datatype
#so i seprate the object dataype feature and intdatatype features

numf=[]
objectf=[]
for h in df.columns:
    if df[h].dtype=='object':
       objectf.append(h)
    else:
        numf.append(h)

# %%
numf
# Out:
# ['Age',
#  'Blood Pressure',
#  'Specific Gravity',
#  'Albumin',
#  'Sugar',
#  'Blood GlucoseRandom',
#  'Blood Urea',
#  'Serum Creatinine',
#  'Sodium',
#  'Potassium',
#  'Hemoglobin',
#  'Packed Cell Volume',
#  'White Blood Cell Count',
#  'Red Blood Cell Count']

# %%
objectf
# Out:
# ['Red Blood Cells',
#  'Pus Cell',
#  'Pus Cell Clumps',
#  'Bacteria',
#  'Hypertension',
#  'Diabetes Mellitus',
#  'Coronary Artery Disease',
#  'Appetite',
#  'Pedal Edema',
#  'Anemia',
#  'Classification']

# %%
#create a two function ,the function is mean and mode 
# mean means the feature mean value take and add null values place using 'fillna()'
# mode means which is more charecter present in the feature and that first index[0] charecter take and fill the 
# nullvalues in the object dtype features
def mean (df,columns):
    meana =df[columns].mean()
    df[columns].fillna(meana,inplace=True)
    
def mode (df,columns):
    modea =df[columns].mode()[0]
    df[columns].fillna(modea,inplace=True)    
    
    


for g in numf:
   mean(df,g)
for f in objectf:
   mode(df,f)

# %%
#after check the null values

df.isnull().sum()
# Out:
# Age                        0
# Blood Pressure             0
# Specific Gravity           0
# Albumin                    0
# Sugar                      0
# Red Blood Cells            0
# Pus Cell                   0
# Pus Cell Clumps            0
# Bacteria                   0
# Blood GlucoseRandom        0
# Blood Urea                 0
# Serum Creatinine           0
# Sodium                     0
# Potassium                  0
# Hemoglobin                 0
# Packed Cell Volume         0
# White Blood Cell Count     0
# Red Blood Cell Count       0
# Hypertension               0
# Diabetes Mellitus          0
# Coronary Artery Disease    0
# Appetite                   0
# Pedal Edema                0
# Anemia                     0
# Classification             0
# dtype: int64

# %%
# check the how many chategries in the objecet datatypes

for u in objectf:
    g=df[u].unique()
    print(u +": ")
    print(g)
    print( )
# Out:
# Red Blood Cells:
# ['normal' 'abnormal']
#
# Pus Cell:
# ['normal' 'abnormal']
#
# Pus Cell Clumps:
# ['notpresent' 'present']
#
# Bacteria:
# ['notpresent' 'present']
#
# Hypertension:
# ['yes' 'no']
#
# Diabetes Mellitus:
# ['yes' 'no' ' yes' '\tno' '\tyes']
#
# Coronary Artery Disease:
# ['no' 'yes' '\tno']
#
# Appetite:
# ['good' 'poor']
#
# Pedal Edema:
# ['no' 'yes']
#
# Anemia:
# ['no' 'yes']
#
# Classification:
# ['ckd' 'ckd\t' 'notckd']

# %%
# i changed the wrong chategries
df['Diabetes Mellitus'].replace({' yes':'yes', '\tno':'no', '\tyes':'yes'},inplace=True)
df['Coronary Artery Disease'].replace({'\tno':'no', },inplace=True)
df['Classification'].replace({'ckd\t':'ckd'},inplace=True)

# %%
print(df['Diabetes Mellitus'].unique())
print(df['Coronary Artery Disease'].unique())
print(df['Classification'].unique())
# Out:
# ['yes' 'no']
# ['no' 'yes']
# ['ckd' 'notckd']

# %%
#now i change object chategries to number chategries  becase ml easily understan and accurately find the patterns
# i using label encoder because all features has two type of charecterstics

from sklearn.preprocessing import LabelEncoder

for d in objectf:
    la=LabelEncoder()
    df[d]=la.fit_transform(df[d])

# %%
df
# Out:
#       Age  Blood Pressure  Specific Gravity  Albumin  Sugar  Red Blood Cells  \
# 0    48.0            80.0             1.020      1.0    0.0                1
# 1     7.0            50.0             1.020      4.0    0.0                1
# 2    62.0            80.0             1.010      2.0    3.0                1
# 3    48.0            70.0             1.005      4.0    0.0                1
# 4    51.0            80.0             1.010      2.0    0.0                1
# ..    ...             ...               ...      ...    ...              ...
# 395  55.0            80.0             1.020      0.0    0.0                1
# 396  42.0            70.0             1.025      0.0    0.0                1
# 397  12.0            80.0             1.020      0.0    0.0                1
# 398  17.0            60.0             1.025      0.0    0.0                1
# 399  58.0            80.0             1.025      0.0    0.0                1
#
# ...

# %%
# annalysing relationship with one feature to another feature

import seaborn as sns
corr_matrix=df.corr()
plt.figure(figsize=(10, 15))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Matrix Heatmap Data")
plt.show()

# %%
# i find the realtionship with target to independent variable

rela = abs(df.corr()['Classification'].sort_values(ascending=False))
rela
# Out:
# Classification             1.000000
# Hemoglobin                 0.729628
# Specific Gravity           0.698957
# Packed Cell Volume         0.690060
# Red Blood Cell Count       0.590913
# Pus Cell                   0.375154
# Sodium                     0.342288
# Red Blood Cells            0.282642
# Potassium                  0.076921
# Bacteria                   0.186871
# White Blood Cell Count     0.205274
# Age                        0.225405
# Coronary Artery Disease    0.236088
# Pus Cell Clumps            0.265313
# Blood Pressure             0.290600
# Serum Creatinine           0.294079
# Anemia                     0.325396
# Sugar                      0.327812
# Blood Urea                 0.372033
# Pedal Edema                0.375154
# Appetite                   0.393341
# Blood GlucoseRandom        0.401374
# Diabetes Mellitus          0.559060
# Hypertension               0.590438
# Albumin                    0.599238
# Name: Classification, dtype: float64

# %%
# i fillter the poor relationship feature with target

filtered_corr = rela[rela< 0.34]
print(filtered_corr)
# Out:
# Red Blood Cells            0.282642
# Potassium                  0.076921
# Bacteria                   0.186871
# White Blood Cell Count     0.205274
# Age                        0.225405
# Coronary Artery Disease    0.236088
# Pus Cell Clumps            0.265313
# Blood Pressure             0.290600
# Serum Creatinine           0.294079
# Anemia                     0.325396
# Sugar                      0.327812
# Name: Classification, dtype: float64

# %%
# filltered poor relationship feature drop

df.drop(filtered_corr.index, axis=1, inplace=True)

# %%
# i see the after preprossing dataframe
df
# Out:
#      Specific Gravity  Albumin  Pus Cell  Blood GlucoseRandom  Blood Urea  \
# 0               1.020      1.0         1           121.000000        36.0
# 1               1.020      4.0         1           148.036517        18.0
# 2               1.010      2.0         1           423.000000        53.0
# 3               1.005      4.0         0           117.000000        56.0
# 4               1.010      2.0         1           106.000000        26.0
# ..                ...      ...       ...                  ...         ...
# 395             1.020      0.0         1           140.000000        49.0
# 396             1.025      0.0         1            75.000000        31.0
# 397             1.020      0.0         1           100.000000        26.0
# 398             1.025      0.0         1           114.000000        50.0
# 399             1.025      0.0         1           131.000000        18.0
#
#          Sodium  Hemoglobin  Packed Cell Volume  Red Blood Cell Count  \
# ...

# %%
df.shape
# Out:
# (400, 14)

# %%
#seprate test and train
X=df.iloc[:,:13]
y=df.iloc[:,13]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
# import classification algorithum
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
#find the accuracy and confussion matrix of the algorithums

model=[DecisionTreeClassifier(),RandomForestClassifier(),KNeighborsClassifier(),SVC()]
for fun in model:
    cla=fun
    cla.fit(X_train,y_train)
    pre=cla.predict(X_test)
    accs= accuracy_score(pre,y_test)
    con=confusion_matrix(pre,y_test)
    
    print(fun,":")
    print("accuracy_score is   : ",accs)
    print("confusion matrix is :")
    print(con)
    print()
# Out:
# DecisionTreeClassifier() :
# accuracy_score is   :  0.98
# confusion matrix is :
# [[63  0]
#  [ 2 35]]
#
# RandomForestClassifier() :
# accuracy_score is   :  1.0
# confusion matrix is :
# [[65  0]
#  [ 0 35]]
#
# KNeighborsClassifier() :
# accuracy_score is   :  0.91
# confusion matrix is :
# [[58  2]
#  [ 7 33]]
#
# SVC() :
# accuracy_score is   :  0.84
# confusion matrix is :
# [[53  4]
#  [12 31]]

# %% [raw]
# ***# RandomForest is the good model its gives falsenegative(FN) and false positive(FP) is 0 and accuracy is 1.0 *****

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#give new datas and check the kidney Disease is or not using Random Forest
gh=(1.020,4.0,1,148.036517,18.0,137.528754,11.3,38.0,4.707435,0,0,0,0)
new_data= np.asarray(gh)
Ra=RandomForestClassifier()
Ra.fit(X_train, y_train) 
output = Ra.predict(new_data.reshape(1, -1))

if output==1:
    print("the patient have Kidney Disease")
else:
    print("the patient doesn't have Kidney Disease")
# Out:
# the patient doesn't have Kidney Disease
